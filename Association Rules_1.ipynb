# %%
#Association Algorithm : - 2nd algorithm of Unsupervised Machine learning 
#1. Apriori Algorithm : -Market Basket Analysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Groceries_dataset.csv')
data.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
#Data Manipulation
#to show all details of member number=1808
data[data['Member_number']==1808]
# Out:
#        Member_number        Date           itemDescription
# 0               1808  21-07-2015            tropical fruit
# 4355            1808  04-02-2015  long life bakery product
# 9090            1808  29-11-2014                      meat
# 11488           1808  15-12-2014                     sugar
# 16149           1808  21-07-2015                rolls/buns
# 20504           1808  04-02-2015       semi-finished bread
# 25239           1808  29-11-2014                whole milk
# 27637           1808  15-12-2014              citrus fruit
# 36088           1808  21-07-2015                     candy
# 38731           1808  15-12-2014                   napkins

# %%
data.shape
# Out:
# (38765, 3)

# %%
#Data Exploration :
#to show first 10 items whose maximum times purchase
data['itemDescription'].value_counts()[0:10]
# Out:
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: itemDescription, dtype: int64

# %%
#To visualise the data 
plt.figure(figsize=(8,16))
data['itemDescription'].value_counts()[0:10].plot(kind="bar")
plt.xlabel('Item Description')
plt.ylabel('Frequency')
f=data['itemDescription'].value_counts()[0:10]
plt.yticks(f)
plt.show()

# %%
data.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
#To add new column Quantity in existing dataset and set value 1 
data['Quantity']=1
data.head()
# Out:
#    Member_number        Date   itemDescription  Quantity
# 0           1808  21-07-2015    tropical fruit         1
# 1           2552  05-01-2015        whole milk         1
# 2           2300  19-09-2015         pip fruit         1
# 3           1187  12-12-2015  other vegetables         1
# 4           3037  01-02-2015        whole milk         1

# %%
data['itemDescription'].unique()
# Out:
# array(['tropical fruit', 'whole milk', 'pip fruit', 'other vegetables',
#        'rolls/buns', 'pot plants', 'citrus fruit', 'beef', 'frankfurter',
#        'chicken', 'butter', 'fruit/vegetable juice',
#        'packaged fruit/vegetables', 'chocolate', 'specialty bar',
#        'butter milk', 'bottled water', 'yogurt', 'sausage', 'brown bread',
#        'hamburger meat', 'root vegetables', 'pork', 'pastry',
#        'canned beer', 'berries', 'coffee', 'misc. beverages', 'ham',
#        'turkey', 'curd cheese', 'red/blush wine',
#        'frozen potato products', 'flour', 'sugar', 'frozen meals',
#        'herbs', 'soda', 'detergent', 'grapes', 'processed cheese', 'fish',
#        'sparkling wine', 'newspapers', 'curd', 'pasta', 'popcorn',
#        'finished products', 'beverages', 'bottled beer', 'dessert',
#        'dog food', 'specialty chocolate', 'condensed milk', 'cleaner',
#        'white wine', 'meat', 'ice cream', 'hard cheese', 'cream cheese ',
# ...

# %%
#unstack() similar to : pivot table (excel)
transactions =  data.groupby(['Member_number','itemDescription'])['Quantity'].sum().unstack().reset_index().set_index('Member_number')
#transaction user defined dataset(pivot table)
transactions
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               NaN       NaN               NaN
# 1001                               NaN       NaN               NaN
# 1002                               NaN       NaN               NaN
# 1003                               NaN       NaN               NaN
# 1004                               NaN       NaN               NaN
# ...                                ...       ...               ...
# 4996                               NaN       NaN               NaN
# 4997                               NaN       NaN               NaN
# 4998                               NaN       NaN               NaN
# 4999                               NaN       NaN               NaN
# 5000                               NaN       NaN               NaN
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
#To fill all NAN value with 0  permanently
transactions=transactions.fillna(0)
transactions
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
#replace values with 1 if freq >0 in pivot table
#create a function 
def encode(x): #x means parameter which hold the value of transactions dataset
    #one by one
    if x<=0:
        return 0
    elif x>0:
        return 1

# %%
#call function
basket=transactions.applymap(encode)

# %%
basket
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
#Apply Apriori Algorithm 
#required library mlxtend
#!pip install mlxtend
#start process for apriori
from mlxtend.frequent_patterns import apriori

# %%
#create the object of class apriori 
frequent_itemset=apriori(basket,min_support=0.06,use_colnames=True)

# %%
frequent_itemset
# Out:
#       support                                    itemsets
# 0    0.078502                                  (UHT-milk)
# 1    0.119548                                      (beef)
# 2    0.079785                                   (berries)
# 3    0.062083                                 (beverages)
# 4    0.158799                              (bottled beer)
# ..        ...                                         ...
# 111  0.082093  (whole milk, rolls/buns, other vegetables)
# 112  0.069266        (whole milk, soda, other vegetables)
# 113  0.071832      (whole milk, yogurt, other vegetables)
# 114  0.065162              (whole milk, soda, rolls/buns)
# 115  0.065931            (whole milk, yogurt, rolls/buns)
#
# [116 rows x 2 columns]

# %%
#Find the rules of association then call class association_rules
from mlxtend.frequent_patterns import association_rules

# %%
#create the object of association_rules class
rules=association_rules(frequent_itemset,metric='lift',min_threshold=1)

# %%
rules
# Out:
#                   antecedents               consequents  antecedent support  \
# 0                (whole milk)                    (beef)            0.458184
# 1                      (beef)              (whole milk)            0.119548
# 2              (bottled beer)        (other vegetables)            0.158799
# 3          (other vegetables)            (bottled beer)            0.376603
# 4              (bottled beer)              (rolls/buns)            0.158799
# ..                        ...                       ...                 ...
# 153  (whole milk, rolls/buns)                  (yogurt)            0.178553
# 154      (yogurt, rolls/buns)              (whole milk)            0.111339
# 155              (whole milk)      (yogurt, rolls/buns)            0.458184
# 156                  (yogurt)  (whole milk, rolls/buns)            0.282966
# 157              (rolls/buns)      (whole milk, yogurt)            0.349666
#
# ...

# %%
#filter
rules[rules['confidence']>0.4
     ]
# Out:
#                         antecedents         consequents  antecedent support  \
# 1                            (beef)        (whole milk)            0.119548
# 2                    (bottled beer)  (other vegetables)            0.158799
# 6                    (bottled beer)        (whole milk)            0.158799
# 9                   (bottled water)  (other vegetables)            0.213699
# 15                  (bottled water)        (whole milk)            0.213699
# 19                    (brown bread)        (whole milk)            0.135967
# 21                         (butter)        (whole milk)            0.126475
# 22                    (canned beer)  (other vegetables)            0.165213
# 24                    (canned beer)        (rolls/buns)            0.165213
# 26                    (canned beer)        (whole milk)            0.165213
# 28                   (citrus fruit)  (other vegetables)            0.185480
# ...
